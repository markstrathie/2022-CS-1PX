# %% [markdown]
# # Cycle 4 Lab Exercises - Functions for Data Structures and Plotting
#
# ### Objectives:
#
# 1. To get more practice devising a data structure, and writing functions to process it
# 2. To make use of a library (`matplotlib`), and practice various kinds of plotting
#
# We’ll be working with a made-up dataset containing information about the production of a fictional vegetable called a poturnip (these data are fake, but their distribution and format are the same as some real agricultural data I have worked with). On each line of the file` poturnip.csv` are four pieces of information associated with a single sale of a shipment of poturnip:
#
# ```
# Price/unit,Production cost/unit,Units produced nationally in month, month,region of sale
# ```
#
# ### Task 0: Designing your data structure
#
# 1. Look at the file` poturnip.csv`
# 2. Devise your own data structure to store the information in this file, and hand-write out your plan.
#     1. Write out an example of how your data structure might store the information in the first three lines of the file
# 3. Write a function to read the information in poturnip.csv and store the information in your data structure.

# %%
def readPoturnips(filename):
    dataStruct = {}
    sale = 0
    try:
        for line in open(filename, 'r'):
            split = line.strip().split(',')
            if len(split)<5:
                print('Problem with line ' + line.strip())
            elif int(split[3]) >12 or int(split[3])<1:
                print('Problem with line ' + line.strip())
            else:
                dataStruct[sale] = {'month': split[3], 'location': split[4], 'price/cost': (split[0],split[1]), 'produced': split[2]}
            sale += 1
        return dataStruct
    except Exception as e:
        print('Failure when reading from ' + filename)
        print('Due to exception ' + str(e))
        return dataStruct
    
readPoturnips('poturnip.csv')
# Out:
# {0: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('31.2', '27.8'),
#   'produced': '32889042'},
#  1: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.4', '31.7'),
#   'produced': '32889042'},
#  2: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.3', '30.1'),
#   'produced': '32889042'},
#  3: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '27.9'),
#   'produced': '32889042'},
#  4: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.7', '32.4'),
#   'produced': '32889042'},
#  5: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '29.3'),
#   'produced': '32889042'},
#  6: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.7', '30.5'),
#   'produced': '32889042'},
#  7: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '31.7'),
#   'produced': '32889042'},
#  8: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.7', '31.1'),
#   'produced': '32889042'},
#  9: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '27'),
#   'produced': '32889042'},
#  10: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '26.7'),
#   'produced': '32889042'},
#  11: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.2', '28.1'),
#   'produced': '32889042'},
#  12: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32', '32.3'),
#   'produced': '32889042'},
#  13: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('36.9', '31.8'),
#   'produced': '32889042'},
#  14: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.3', '26.5'),
#   'produced': '32889042'},
#  15: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.5', '30.9'),
#   'produced': '32889042'},
#  16: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.6', '29.4'),
#   'produced': '32889042'},
#  17: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '31.3'),
#   'produced': '32889042'},
#  18: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32', '30.3'),
#   'produced': '32889042'},
#  19: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.5', '23.8'),
#   'produced': '32889042'},
#  20: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.6', '26.3'),
#   'produced': '32889042'},
#  21: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '29.9'),
#   'produced': '32889042'},
#  22: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38', '25'),
#   'produced': '32889042'},
#  23: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('31.9', '28.8'),
#   'produced': '32889042'},
#  24: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.9', '29.6'),
#   'produced': '32889042'},
#  25: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.6', '29.9'),
#   'produced': '32889042'},
#  26: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.8', '29.5'),
#   'produced': '32889042'},
#  27: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.8', '32'),
#   'produced': '32889042'},
#  28: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.5', '32'),
#   'produced': '32889042'},
#  29: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.2', '31.1'),
#   'produced': '32889042'},
#  30: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.4', '30.7'),
#   'produced': '32889042'},
#  31: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.3', '34.3'),
#   'produced': '32889042'},
#  32: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.4', '27.2'),
#   'produced': '32889042'},
#  33: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.6', '30.7'),
#   'produced': '32889042'},
#  34: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.9', '26'),
#   'produced': '32889042'},
#  35: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '27.1'),
#   'produced': '32889042'},
#  36: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '29.5'),
#   'produced': '32889042'},
#  37: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32', '30.5'),
#   'produced': '32889042'},
#  38: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '26.3'),
#   'produced': '32889042'},
#  39: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '28.6'),
#   'produced': '32889042'},
#  40: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.4', '31.8'),
#   'produced': '25202584'},
#  41: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30', '22.5'),
#   'produced': '25202584'},
#  42: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30', '24.5'),
#   'produced': '25202584'},
#  43: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.5', '26.5'),
#   'produced': '25202584'},
#  44: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.5', '29.1'),
#   'produced': '25202584'},
#  45: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.1', '22.6'),
#   'produced': '25202584'},
#  46: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.4', '25'),
#   'produced': '25202584'},
#  47: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.9', '31'),
#   'produced': '25202584'},
#  48: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('28.9', '26.1'),
#   'produced': '25202584'},
#  49: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.7', '24.2'),
#   'produced': '25202584'},
#  50: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '29.7'),
#   'produced': '25202584'},
#  51: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.3', '27.1'),
#   'produced': '25202584'},
#  52: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.7', '27.4'),
#   'produced': '25202584'},
#  53: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.3', '27.7'),
#   'produced': '25202584'},
#  54: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.8', '25.1'),
#   'produced': '25202584'},
#  55: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.8', '22.4'),
#   'produced': '25202584'},
#  56: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.9', '21.4'),
#   'produced': '25202584'},
#  57: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '30.1'),
#   'produced': '25202584'},
#  58: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.7', '26.4'),
#   'produced': '25202584'},
#  59: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.2', '23.9'),
#   'produced': '25202584'},
#  60: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.1', '25.4'),
#   'produced': '25202584'},
#  61: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.9', '25.9'),
#   'produced': '25202584'},
#  62: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '27.7'),
#   'produced': '25202584'},
#  63: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.4', '28'),
#   'produced': '25202584'},
#  64: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '24.4'),
#   'produced': '25202584'},
#  65: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.9', '22.8'),
#   'produced': '25202584'},
#  66: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.8', '24.9'),
#   'produced': '25202584'},
#  67: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.3', '27.4'),
#   'produced': '25202584'},
#  68: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.1', '21.7'),
#   'produced': '25202584'},
#  69: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.6', '28.1'),
#   'produced': '25202584'},
#  70: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.3', '26.1'),
#   'produced': '25202584'},
#  71: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '24.8'),
#   'produced': '25202584'},
#  72: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.9', '27.7'),
#   'produced': '25202584'},
#  73: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.6', '21.6'),
#   'produced': '25202584'},
#  74: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '28.4'),
#   'produced': '25202584'},
#  75: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.1', '24.8'),
#   'produced': '25202584'},
#  76: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.4', '24.3'),
#   'produced': '25202584'},
#  77: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.5', '29.9'),
#   'produced': '25202584'},
#  78: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.3', '25.5'),
#   'produced': '25202584'},
#  79: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.4', '25'),
#   'produced': '25202584'},
#  80: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '25.5'),
#   'produced': '34192592'},
#  81: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '30'),
#   'produced': '34192592'},
#  82: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '22.2'),
#   'produced': '34192592'},
#  83: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '28.8'),
#   'produced': '34192592'},
#  84: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.6', '26.6'),
#   'produced': '34192592'},
#  85: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '29.6'),
#   'produced': '34192592'},
#  86: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '31.5'),
#   'produced': '34192592'},
#  87: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '28.1'),
#   'produced': '34192592'},
#  88: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.7', '30.8'),
#   'produced': '34192592'},
#  89: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.2', '27.2'),
#   'produced': '34192592'},
#  90: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '31'),
#   'produced': '34192592'},
#  91: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.3', '32'),
#   'produced': '34192592'},
#  92: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.7', '33.6'),
#   'produced': '34192592'},
#  93: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '30.2'),
#   'produced': '34192592'},
#  94: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.6', '30.9'),
#   'produced': '34192592'},
#  95: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('29', '29.4'),
#   'produced': '34192592'},
#  96: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '29.2'),
#   'produced': '34192592'},
#  97: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.1'),
#   'produced': '34192592'},
#  98: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '30.5'),
#   'produced': '34192592'},
#  99: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.9', '29'),
#   'produced': '34192592'},
#  100: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '28.8'),
#   'produced': '34192592'},
#  101: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.2', '32.2'),
#   'produced': '34192592'},
#  102: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.5', '27.3'),
#   'produced': '34192592'},
#  103: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '27.6'),
#   'produced': '34192592'},
#  104: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '26.8'),
#   'produced': '34192592'},
#  105: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28', '30.8'),
#   'produced': '34192592'},
#  106: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '29.8'),
#   'produced': '34192592'},
#  107: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.8'),
#   'produced': '34192592'},
#  108: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '23.8'),
#   'produced': '34192592'},
#  109: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.5', '27'),
#   'produced': '34192592'},
#  110: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.7', '30.8'),
#   'produced': '34192592'},
#  111: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.6', '28.9'),
#   'produced': '34192592'},
#  112: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('26.7', '32.4'),
#   'produced': '34192592'},
#  113: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.8', '28.6'),
#   'produced': '34192592'},
#  114: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('29', '31.6'),
#   'produced': '34192592'},
#  115: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.5', '30.5'),
#   'produced': '34192592'},
#  116: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.1', '30.1'),
#   'produced': '34192592'},
#  117: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.7', '28.7'),
#   'produced': '34192592'},
#  118: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '28.3'),
#   'produced': '34192592'},
#  119: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.4', '30.3'),
#   'produced': '34192592'},
#  120: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.4', '20.9'),
#   'produced': '31210725'},
#  121: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('25.9', '23.1'),
#   'produced': '31210725'},
#  122: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.4', '14.5'),
#   'produced': '31210725'},
#  123: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '21'),
#   'produced': '31210725'},
#  124: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.1', '21.7'),
#   'produced': '31210725'},
#  125: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '24.4'),
#   'produced': '31210725'},
#  126: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.1', '23.8'),
#   'produced': '31210725'},
#  127: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '22.2'),
#   'produced': '31210725'},
#  128: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '25.4'),
#   'produced': '31210725'},
#  129: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.9', '18.3'),
#   'produced': '31210725'},
#  130: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.1', '22.1'),
#   'produced': '31210725'},
#  131: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '23'),
#   'produced': '31210725'},
#  132: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '25.3'),
#   'produced': '31210725'},
#  133: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.2', '23.6'),
#   'produced': '31210725'},
#  134: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.8', '23.4'),
#   'produced': '31210725'},
#  135: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '21.4'),
#   'produced': '31210725'},
#  136: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '25.1'),
#   'produced': '31210725'},
#  137: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '19.6'),
#   'produced': '31210725'},
#  138: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '21.7'),
#   'produced': '31210725'},
#  139: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.6', '19.5'),
#   'produced': '31210725'},
#  140: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.7', '25.5'),
#   'produced': '31210725'},
#  141: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '20.2'),
#   'produced': '31210725'},
#  142: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.6', '20.3'),
#   'produced': '31210725'},
#  143: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.5', '21.2'),
#   'produced': '31210725'},
#  144: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '18.2'),
#   'produced': '31210725'},
#  145: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('25.8', '22.8'),
#   'produced': '31210725'},
#  146: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27', '25.4'),
#   'produced': '31210725'},
#  147: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.8', '21.4'),
#   'produced': '31210725'},
#  148: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.6', '22.8'),
#   'produced': '31210725'},
#  149: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.4', '20.4'),
#   'produced': '31210725'},
#  150: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '19.7'),
#   'produced': '31210725'},
#  151: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.2', '22.7'),
#   'produced': '31210725'},
#  152: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '25.4'),
#   'produced': '31210725'},
#  153: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '21.1'),
#   'produced': '31210725'},
#  154: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27', '21.5'),
#   'produced': '31210725'},
#  155: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '23.2'),
#   'produced': '31210725'},
#  156: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26', '20.5'),
#   'produced': '31210725'},
#  157: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.3', '24.9'),
#   'produced': '31210725'},
#  158: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26', '21'),
#   'produced': '31210725'},
#  159: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '27.7'),
#   'produced': '31210725'},
#  160: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '17.4'),
#   'produced': '30543330'},
#  161: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '20.6'),
#   'produced': '30543330'},
#  162: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '21.2'),
#   'produced': '30543330'},
#  163: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.5', '21.2'),
#   'produced': '30543330'},
#  164: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '24.5'),
#   'produced': '30543330'},
#  165: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.4'),
#   'produced': '30543330'},
#  166: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.1'),
#   'produced': '30543330'},
#  167: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '16.3'),
#   'produced': '30543330'},
#  168: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '22.5'),
#   'produced': '30543330'},
#  169: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '21.7'),
#   'produced': '30543330'},
#  170: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.4', '23.2'),
#   'produced': '30543330'},
#  171: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '24.6'),
#   'produced': '30543330'},
#  172: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.7', '26.2'),
#   'produced': '30543330'},
#  173: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '22.7'),
#   'produced': '30543330'},
#  174: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.5', '24.1'),
#   'produced': '30543330'},
#  175: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '22.6'),
#   'produced': '30543330'},
#  176: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('26.1', '20.9'),
#   'produced': '30543330'},
#  177: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '21.3'),
#   'produced': '30543330'},
#  178: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '19.7'),
#   'produced': '30543330'},
#  179: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '19.4'),
#   'produced': '30543330'},
#  180: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.6', '21.3'),
#   'produced': '30543330'},
#  181: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.1', '23'),
#   'produced': '30543330'},
#  182: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '22.5'),
#   'produced': '30543330'},
#  183: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.7', '22.3'),
#   'produced': '30543330'},
#  184: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.4', '26.6'),
#   'produced': '30543330'},
#  185: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25', '19'),
#   'produced': '30543330'},
#  186: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25', '21.1'),
#   'produced': '30543330'},
#  187: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.4', '20.8'),
#   'produced': '30543330'},
#  188: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '21.2'),
#   'produced': '30543330'},
#  189: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.7', '22'),
#   'produced': '30543330'},
#  190: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.6', '20.2'),
#   'produced': '30543330'},
#  191: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.4', '18.6'),
#   'produced': '30543330'},
#  192: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '23.3'),
#   'produced': '30543330'},
#  193: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '20'),
#   'produced': '30543330'},
#  194: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '24.9'),
#   'produced': '30543330'},
#  195: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.8', '19.6'),
#   'produced': '30543330'},
#  196: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.2', '24.6'),
#   'produced': '30543330'},
#  197: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '20.2'),
#   'produced': '30543330'},
#  198: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.2', '21.2'),
#   'produced': '30543330'},
#  199: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '19.5'),
#   'produced': '30543330'},
#  200: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.9', '30'),
#   'produced': '33581803'},
#  201: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.3', '29.8'),
#   'produced': '33581803'},
#  202: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.3', '31.2'),
#   'produced': '33581803'},
#  203: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '27.5'),
#   'produced': '33581803'},
#  204: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.5', '27'),
#   'produced': '33581803'},
#  205: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '31'),
#   'produced': '33581803'},
#  206: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.5', '26.5'),
#   'produced': '33581803'},
#  207: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '32.3'),
#   'produced': '33581803'},
#  208: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '28.1'),
#   'produced': '33581803'},
#  209: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.6', '28.7'),
#   'produced': '33581803'},
#  210: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.4', '30.1'),
#   'produced': '33581803'},
#  211: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40', '26.4'),
#   'produced': '33581803'},
#  212: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '26.3'),
#   'produced': '33581803'},
#  213: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '36.9'),
#   'produced': '33581803'},
#  214: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.8', '29.9'),
#   'produced': '33581803'},
#  215: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '32.4'),
#   'produced': '33581803'},
#  216: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.4', '30.2'),
#   'produced': '33581803'},
#  217: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.8', '29.3'),
#   'produced': '33581803'},
#  218: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.3', '30'),
#   'produced': '33581803'},
#  219: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.1', '27'),
#   'produced': '33581803'},
#  220: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '26.7'),
#   'produced': '33581803'},
#  221: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.6', '26.9'),
#   'produced': '33581803'},
#  222: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('38.8', '31.2'),
#   'produced': '33581803'},
#  223: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.3', '24.6'),
#   'produced': '33581803'},
#  224: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.9', '31.4'),
#   'produced': '33581803'},
#  225: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '32.8'),
#   'produced': '33581803'},
#  226: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.5', '30.9'),
#   'produced': '33581803'},
#  227: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '30.6'),
#   'produced': '33581803'},
#  228: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.8', '30.5'),
#   'produced': '33581803'},
#  229: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.2', '25.7'),
#   'produced': '33581803'},
#  230: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '29.8'),
#   'produced': '33581803'},
#  231: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.6', '31.9'),
#   'produced': '33581803'},
#  232: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '31.8'),
#   'produced': '33581803'},
#  233: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.4', '24.4'),
#   'produced': '33581803'},
#  234: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('38.8', '28'),
#   'produced': '33581803'},
#  235: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.3', '27.9'),
#   'produced': '33581803'},
#  236: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.1', '31.7'),
#   'produced': '33581803'},
#  237: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.5', '32'),
#   'produced': '33581803'},
#  238: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40', '29.9'),
#   'produced': '33581803'},
#  239: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.2', '27.7'),
#   'produced': '33581803'},
#  240: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '23.2'),
#   'produced': '35301548'},
#  241: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '23.7'),
#   'produced': '35301548'},
#  242: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '21.3'),
#   'produced': '35301548'},
#  243: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.8', '21.7'),
#   'produced': '35301548'},
#  244: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '24'),
#   'produced': '35301548'},
#  245: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.3', '24.6'),
#   'produced': '35301548'},
#  246: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '22.6'),
#   'produced': '35301548'},
#  247: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '21.7'),
#   'produced': '35301548'},
#  248: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.6', '24.1'),
#   'produced': '35301548'},
#  249: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.7', '23'),
#   'produced': '35301548'},
#  250: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.4', '21.4'),
#   'produced': '35301548'},
#  251: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.1', '18.9'),
#   'produced': '35301548'},
#  252: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('26.2', '21.1'),
#   'produced': '35301548'},
#  253: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '25.6'),
#   'produced': '35301548'},
#  254: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('23.9', '22.2'),
#   'produced': '35301548'},
#  255: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25', '23.6'),
#   'produced': '35301548'},
#  256: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '24.1'),
#   'produced': '35301548'},
#  257: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '19.7'),
#   'produced': '35301548'},
#  258: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.5'),
#   'produced': '35301548'},
#  259: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '23'),
#   'produced': '35301548'},
#  260: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '18.7'),
#   'produced': '35301548'},
#  261: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '25.4'),
#   'produced': '35301548'},
#  262: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '21.5'),
#   'produced': '35301548'},
#  263: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '22.6'),
#   'produced': '35301548'},
#  264: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '26.8'),
#   'produced': '35301548'},
#  265: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '21.9'),
#   'produced': '35301548'},
#  266: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.8'),
#   'produced': '35301548'},
#  267: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.2'),
#   'produced': '35301548'},
#  268: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '21'),
#   'produced': '35301548'},
#  269: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.5'),
#   'produced': '35301548'},
#  270: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '21.1'),
#   'produced': '35301548'},
#  271: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.2', '21.1'),
#   'produced': '35301548'},
#  272: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.8', '20.3'),
#   'produced': '35301548'},
#  273: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '22.3'),
#   'produced': '35301548'},
#  274: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('23.9', '24.3'),
#   'produced': '35301548'},
#  275: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.7', '18.3'),
#   'produced': '35301548'},
#  276: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '25.3'),
#   'produced': '35301548'},
#  277: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.8', '23.3'),
#   'produced': '35301548'},
#  278: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('26.2', '18.5'),
#   'produced': '35301548'},
#  279: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.6', '21.9'),
#   'produced': '35301548'},
#  280: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '28.1'),
#   'produced': '31673550'},
#  281: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28', '25.9'),
#   'produced': '31673550'},
#  282: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '25.7'),
#   'produced': '31673550'},
#  283: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '23.4'),
#   'produced': '31673550'},
#  284: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('29', '22.1'),
#   'produced': '31673550'},
#  285: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '27.1'),
#   'produced': '31673550'},
#  286: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '24.1'),
#   'produced': '31673550'},
#  287: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.1', '27.2'),
#   'produced': '31673550'},
#  288: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '25.7'),
#   'produced': '31673550'},
#  289: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28', '27.7'),
#   'produced': '31673550'},
#  290: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.9', '18.8'),
#   'produced': '31673550'},
#  291: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.9', '27.9'),
#   'produced': '31673550'},
#  292: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28', '25.6'),
#   'produced': '31673550'},
#  293: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.4', '28'),
#   'produced': '31673550'},
#  294: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.7', '25.9'),
#   'produced': '31673550'},
#  295: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.5', '19.7'),
#   'produced': '31673550'},
#  296: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '26.4'),
#   'produced': '31673550'},
#  297: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.1', '25.9'),
#   'produced': '31673550'},
#  298: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.6', '25.1'),
#   'produced': '31673550'},
#  299: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '22.7'),
#   'produced': '31673550'},
#  300: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.4', '29.2'),
#   'produced': '31673550'},
#  301: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '22.8'),
#   'produced': '31673550'},
#  302: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.4', '26.8'),
#   'produced': '31673550'},
#  303: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '20'),
#   'produced': '31673550'},
#  304: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.1', '22.7'),
#   'produced': '31673550'},
#  305: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.7', '22.6'),
#   'produced': '31673550'},
#  306: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.5', '28'),
#   'produced': '31673550'},
#  307: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.1', '25'),
#   'produced': '31673550'},
#  308: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '21.7'),
#   'produced': '31673550'},
#  309: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '29.8'),
#   'produced': '31673550'},
#  310: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('29.1', '24.9'),
#   'produced': '31673550'},
#  311: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.3', '24.3'),
#   'produced': '31673550'},
#  312: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '26.3'),
#   'produced': '31673550'},
#  313: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.5', '23.4'),
#   'produced': '31673550'},
#  314: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '22.6'),
#   'produced': '31673550'},
#  315: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.3', '27.1'),
#   'produced': '31673550'},
#  316: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.5', '26.9'),
#   'produced': '31673550'},
#  317: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '25.5'),
#   'produced': '31673550'},
#  318: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('26.5', '28.4'),
#   'produced': '31673550'},
#  319: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.3'),
#   'produced': '31673550'},
#  320: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.8', '24.5'),
#   'produced': '40571096'},
#  321: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.2', '26'),
#   'produced': '40571096'},
#  322: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.2', '24'),
#   'produced': '40571096'},
#  323: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23', '21.7'),
#   'produced': '40571096'},
#  324: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.3', '26.2'),
#   'produced': '40571096'},
#  325: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.6', '24.8'),
#   'produced': '40571096'},
#  326: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.8', '28.4'),
#   'produced': '40571096'},
#  327: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '25.8'),
#   'produced': '40571096'},
#  328: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '25.1'),
#   'produced': '40571096'},
#  329: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.2', '23.7'),
#   'produced': '40571096'},
#  330: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.3', '24.5'),
#   'produced': '40571096'},
#  331: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.1', '19.6'),
#   'produced': '40571096'},
#  332: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.8', '22.6'),
#   'produced': '40571096'},
#  333: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23', '23'),
#   'produced': '40571096'},
#  334: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.7', '27.5'),
#   'produced': '40571096'},
#  335: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.1', '24.7'),
#   'produced': '40571096'},
#  336: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.6', '25.1'),
#   'produced': '40571096'},
#  337: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.6', '27.2'),
#   'produced': '40571096'},
#  338: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '23.6'),
#   'produced': '40571096'},
#  339: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.1', '24.2'),
#   'produced': '40571096'},
#  340: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '17.6'),
#   'produced': '40571096'},
#  341: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.5', '24.1'),
#   'produced': '40571096'},
#  342: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.3', '29.9'),
#   'produced': '40571096'},
#  343: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.3', '28'),
#   'produced': '40571096'},
#  344: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.9', '24.8'),
#   'produced': '40571096'},
#  345: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.2', '25.6'),
#   'produced': '40571096'},
#  346: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '24'),
#   'produced': '40571096'},
#  347: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('21.5', '26'),
#   'produced': '40571096'},
#  348: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.5', '22.8'),
#   'produced': '40571096'},
#  349: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('24.1', '30.6'),
#   'produced': '40571096'},
#  350: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.7', '25.7'),
#   'produced': '40571096'},
#  351: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.9', '25.5'),
#   'produced': '40571096'},
#  352: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.1', '22.3'),
#   'produced': '40571096'},
#  353: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.1', '26'),
#   'produced': '40571096'},
#  354: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.4', '21.4'),
#   'produced': '40571096'},
#  355: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.5', '28.2'),
#   'produced': '40571096'},
#  356: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.3', '19.6'),
#   'produced': '40571096'},
#  357: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.4', '26.4'),
#   'produced': '40571096'},
#  358: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '24.5'),
#   'produced': '40571096'},
#  359: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.6', '29.7'),
#   'produced': '40571096'},
#  360: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.1', '29.8'),
#   'produced': '27967161'},
#  361: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.1', '31'),
#   'produced': '27967161'},
#  362: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.9', '25.7'),
#   'produced': '27967161'},
#  363: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.7', '25.7'),
#   'produced': '27967161'},
#  364: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.6', '23.1'),
#   'produced': '27967161'},
#  365: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '27.2'),
#   'produced': '27967161'},
#  366: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '30.9'),
#   'produced': '27967161'},
#  367: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.5', '29.1'),
#   'produced': '27967161'},
#  368: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.9', '33.3'),
#   'produced': '27967161'},
#  369: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.2', '27.8'),
#   'produced': '27967161'},
#  370: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.4', '26.5'),
#   'produced': '27967161'},
#  371: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('33.9', '28.2'),
#   'produced': '27967161'},
#  372: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('36', '29'),
#   'produced': '27967161'},
#  373: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.1', '32.5'),
#   'produced': '27967161'},
#  374: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.5', '28.5'),
#   'produced': '27967161'},
#  375: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.9', '31'),
#   'produced': '27967161'},
#  376: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41', '28'),
#   'produced': '27967161'},
#  377: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '31.6'),
#   'produced': '27967161'},
#  378: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.8', '31.6'),
#   'produced': '27967161'},
#  379: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.7', '30.5'),
#   'produced': '27967161'},
#  380: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.9', '31.9'),
#   'produced': '27967161'},
#  381: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '27.2'),
#   'produced': '27967161'},
#  382: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.1', '29.4'),
#   'produced': '27967161'},
#  383: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.8', '29.9'),
#   'produced': '27967161'},
#  384: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.3', '29.5'),
#   'produced': '27967161'},
#  385: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.6', '27.1'),
#   'produced': '27967161'},
#  386: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '27.8'),
#   'produced': '27967161'},
#  387: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.9', '29.4'),
#   'produced': '27967161'},
#  388: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.5', '29.5'),
#   'produced': '27967161'},
#  389: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.2', '25.5'),
#   'produced': '27967161'},
#  390: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.4', '28.7'),
#   'produced': '27967161'},
#  391: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('42.2', '28.6'),
#   'produced': '27967161'},
#  392: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('42', '28.2'),
#   'produced': '27967161'},
#  393: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35', '28.2'),
#   'produced': '27967161'},
#  394: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.8', '24.9'),
#   'produced': '27967161'},
#  395: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '29.7'),
#   'produced': '27967161'},
#  396: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.4', '28.1'),
#   'produced': '27967161'},
#  397: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '31.4'),
#   'produced': '27967161'},
#  398: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '29.8'),
#   'produced': '27967161'},
#  399: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.3', '31.7'),
#   'produced': '27967161'},
#  400: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.1', '18.7'),
#   'produced': '36604264'},
#  401: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '22.3'),
#   'produced': '36604264'},
#  402: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.4', '20.8'),
#   'produced': '36604264'},
#  403: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '25.5'),
#   'produced': '36604264'},
#  404: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.8', '23'),
#   'produced': '36604264'},
#  405: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '23.7'),
#   'produced': '36604264'},
#  406: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '22'),
#   'produced': '36604264'},
#  407: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.7', '22.9'),
#   'produced': '36604264'},
#  408: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.7', '22.5'),
#   'produced': '36604264'},
#  409: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '23.9'),
#   'produced': '36604264'},
#  410: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25', '18.7'),
#   'produced': '36604264'},
#  411: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.2', '26.6'),
#   'produced': '36604264'},
#  412: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '17.7'),
#   'produced': '36604264'},
#  413: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('23.9', '19.7'),
#   'produced': '36604264'},
#  414: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '22.4'),
#   'produced': '36604264'},
#  415: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '19.7'),
#   'produced': '36604264'},
#  416: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '25.7'),
#   'produced': '36604264'},
#  417: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '24.7'),
#   'produced': '36604264'},
#  418: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '22.7'),
#   'produced': '36604264'},
#  419: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.2', '21.8'),
#   'produced': '36604264'},
#  420: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.2', '25.9'),
#   'produced': '36604264'},
#  421: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.8', '23.2'),
#   'produced': '36604264'},
#  422: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.7', '19.2'),
#   'produced': '36604264'},
#  423: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.4', '19.8'),
#   'produced': '36604264'},
#  424: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24', '21.8'),
#   'produced': '36604264'},
#  425: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.5', '21.2'),
#   'produced': '36604264'},
#  426: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.3', '27'),
#   'produced': '36604264'},
#  427: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.8', '23.2'),
#   'produced': '36604264'},
#  428: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '25.2'),
#   'produced': '36604264'},
#  429: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.3', '20.9'),
#   'produced': '36604264'},
#  430: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.7', '22'),
#   'produced': '36604264'},
#  431: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '24.3'),
#   'produced': '36604264'},
#  432: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.9', '23.9'),
#   'produced': '36604264'},
#  433: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '21.3'),
#   'produced': '36604264'},
#  434: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '21'),
#   'produced': '36604264'},
#  435: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '24'),
#   'produced': '36604264'},
#  436: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.3', '19.4'),
#   'produced': '36604264'},
#  437: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '25.7'),
#   'produced': '36604264'},
#  438: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.6', '22.7'),
#   'produced': '36604264'},
#  439: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '24.9'),
#   'produced': '36604264'},
#  440: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '25.4'),
#   'produced': '33479143'},
#  441: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.8', '25.7'),
#   'produced': '33479143'},
#  442: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '30.8'),
#   'produced': '33479143'},
#  443: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '30.2'),
#   'produced': '33479143'},
#  444: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.8', '36'),
#   'produced': '33479143'},
#  445: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '27'),
#   'produced': '33479143'},
#  446: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '26.8'),
#   'produced': '33479143'},
#  447: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '31.8'),
#   'produced': '33479143'},
#  448: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.9', '30.5'),
#   'produced': '33479143'},
#  449: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '27.3'),
#   'produced': '33479143'},
#  450: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32', '30.9'),
#   'produced': '33479143'},
#  451: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.5', '29.1'),
#   'produced': '33479143'},
#  452: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.9', '26.6'),
#   'produced': '33479143'},
#  453: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('30.8', '28.6'),
#   'produced': '33479143'},
#  454: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '29.3'),
#   'produced': '33479143'},
#  455: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('33.4', '27.9'),
#   'produced': '33479143'},
#  456: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.8', '31.3'),
#   'produced': '33479143'},
#  457: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.5', '27.4'),
#   'produced': '33479143'},
#  458: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('33', '31.6'),
#   'produced': '33479143'},
#  459: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32', '28.4'),
#   'produced': '33479143'},
#  460: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '25.9'),
#   'produced': '33479143'},
#  461: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32', '32.1'),
#   'produced': '33479143'},
#  462: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '34.6'),
#   'produced': '33479143'},
#  463: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.2', '30.7'),
#   'produced': '33479143'},
#  464: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '32.9'),
#   'produced': '33479143'},
#  465: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '27.9'),
#   'produced': '33479143'},
#  466: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.7', '32.5'),
#   'produced': '33479143'},
#  467: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.6', '28.1'),
#   'produced': '33479143'},
#  468: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '30.9'),
#   'produced': '33479143'},
#  469: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.8', '32.3'),
#   'produced': '33479143'},
#  470: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '28.4'),
#   'produced': '33479143'},
#  471: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.1', '25.3'),
#   'produced': '33479143'},
#  472: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.5', '25.1'),
#   'produced': '33479143'},
#  473: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.8', '25.7'),
#   'produced': '33479143'},
#  474: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.5', '25.6'),
#   'produced': '33479143'},
#  475: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('33.2', '30'),
#   'produced': '33479143'},
#  476: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.7', '28.1'),
#   'produced': '33479143'},
#  477: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '33.2'),
#   'produced': '33479143'},
#  478: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.4', '25.9'),
#   'produced': '33479143'},
#  479: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.5', '28.5'),
#   'produced': '33479143'}}

# %% [markdown]
# ### Task 1: Breaking your own code
# Now a bit of fun - try to break your file reading function!  Add a line to `poturnip.csv` that causes your reading function to throw a runtime exception.  Now, add some error-checking or an exception to your function that deals with it.

# %%
readPoturnips('poturnip.csv')
# Out:
# {0: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('31.2', '27.8'),
#   'produced': '32889042'},
#  1: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.4', '31.7'),
#   'produced': '32889042'},
#  2: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.3', '30.1'),
#   'produced': '32889042'},
#  3: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '27.9'),
#   'produced': '32889042'},
#  4: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.7', '32.4'),
#   'produced': '32889042'},
#  5: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '29.3'),
#   'produced': '32889042'},
#  6: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.7', '30.5'),
#   'produced': '32889042'},
#  7: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '31.7'),
#   'produced': '32889042'},
#  8: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.7', '31.1'),
#   'produced': '32889042'},
#  9: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '27'),
#   'produced': '32889042'},
#  10: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.1', '26.7'),
#   'produced': '32889042'},
#  11: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.2', '28.1'),
#   'produced': '32889042'},
#  12: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32', '32.3'),
#   'produced': '32889042'},
#  13: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('36.9', '31.8'),
#   'produced': '32889042'},
#  14: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.3', '26.5'),
#   'produced': '32889042'},
#  15: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.5', '30.9'),
#   'produced': '32889042'},
#  16: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.6', '29.4'),
#   'produced': '32889042'},
#  17: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '31.3'),
#   'produced': '32889042'},
#  18: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32', '30.3'),
#   'produced': '32889042'},
#  19: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.5', '23.8'),
#   'produced': '32889042'},
#  20: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.6', '26.3'),
#   'produced': '32889042'},
#  21: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '29.9'),
#   'produced': '32889042'},
#  22: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38', '25'),
#   'produced': '32889042'},
#  23: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('31.9', '28.8'),
#   'produced': '32889042'},
#  24: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.9', '29.6'),
#   'produced': '32889042'},
#  25: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.6', '29.9'),
#   'produced': '32889042'},
#  26: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.8', '29.5'),
#   'produced': '32889042'},
#  27: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.8', '32'),
#   'produced': '32889042'},
#  28: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.5', '32'),
#   'produced': '32889042'},
#  29: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.2', '31.1'),
#   'produced': '32889042'},
#  30: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.4', '30.7'),
#   'produced': '32889042'},
#  31: {'month': '2',
#   'location': 'Ashire',
#   'price/cost': ('32.3', '34.3'),
#   'produced': '32889042'},
#  32: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.4', '27.2'),
#   'produced': '32889042'},
#  33: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('37.6', '30.7'),
#   'produced': '32889042'},
#  34: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('31.9', '26'),
#   'produced': '32889042'},
#  35: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '27.1'),
#   'produced': '32889042'},
#  36: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '29.5'),
#   'produced': '32889042'},
#  37: {'month': '2',
#   'location': 'Bshire',
#   'price/cost': ('32', '30.5'),
#   'produced': '32889042'},
#  38: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '26.3'),
#   'produced': '32889042'},
#  39: {'month': '2',
#   'location': 'Cshire',
#   'price/cost': ('38.2', '28.6'),
#   'produced': '32889042'},
#  40: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.4', '31.8'),
#   'produced': '25202584'},
#  41: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30', '22.5'),
#   'produced': '25202584'},
#  42: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30', '24.5'),
#   'produced': '25202584'},
#  43: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.5', '26.5'),
#   'produced': '25202584'},
#  44: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.5', '29.1'),
#   'produced': '25202584'},
#  45: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.1', '22.6'),
#   'produced': '25202584'},
#  46: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.4', '25'),
#   'produced': '25202584'},
#  47: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.9', '31'),
#   'produced': '25202584'},
#  48: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('28.9', '26.1'),
#   'produced': '25202584'},
#  49: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.7', '24.2'),
#   'produced': '25202584'},
#  50: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '29.7'),
#   'produced': '25202584'},
#  51: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.3', '27.1'),
#   'produced': '25202584'},
#  52: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.7', '27.4'),
#   'produced': '25202584'},
#  53: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.3', '27.7'),
#   'produced': '25202584'},
#  54: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.8', '25.1'),
#   'produced': '25202584'},
#  55: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.8', '22.4'),
#   'produced': '25202584'},
#  56: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.9', '21.4'),
#   'produced': '25202584'},
#  57: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '30.1'),
#   'produced': '25202584'},
#  58: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.7', '26.4'),
#   'produced': '25202584'},
#  59: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.2', '23.9'),
#   'produced': '25202584'},
#  60: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.1', '25.4'),
#   'produced': '25202584'},
#  61: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.9', '25.9'),
#   'produced': '25202584'},
#  62: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '27.7'),
#   'produced': '25202584'},
#  63: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.4', '28'),
#   'produced': '25202584'},
#  64: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '24.4'),
#   'produced': '25202584'},
#  65: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.9', '22.8'),
#   'produced': '25202584'},
#  66: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.8', '24.9'),
#   'produced': '25202584'},
#  67: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('30.3', '27.4'),
#   'produced': '25202584'},
#  68: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.1', '21.7'),
#   'produced': '25202584'},
#  69: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.6', '28.1'),
#   'produced': '25202584'},
#  70: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.3', '26.1'),
#   'produced': '25202584'},
#  71: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('29.9', '24.8'),
#   'produced': '25202584'},
#  72: {'month': '10',
#   'location': 'Cshire',
#   'price/cost': ('29.9', '27.7'),
#   'produced': '25202584'},
#  73: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.6', '21.6'),
#   'produced': '25202584'},
#  74: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.9', '28.4'),
#   'produced': '25202584'},
#  75: {'month': '10',
#   'location': 'Bshire',
#   'price/cost': ('30.1', '24.8'),
#   'produced': '25202584'},
#  76: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('29.4', '24.3'),
#   'produced': '25202584'},
#  77: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.5', '29.9'),
#   'produced': '25202584'},
#  78: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.3', '25.5'),
#   'produced': '25202584'},
#  79: {'month': '10',
#   'location': 'Ashire',
#   'price/cost': ('30.4', '25'),
#   'produced': '25202584'},
#  80: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '25.5'),
#   'produced': '34192592'},
#  81: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '30'),
#   'produced': '34192592'},
#  82: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '22.2'),
#   'produced': '34192592'},
#  83: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '28.8'),
#   'produced': '34192592'},
#  84: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.6', '26.6'),
#   'produced': '34192592'},
#  85: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '29.6'),
#   'produced': '34192592'},
#  86: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '31.5'),
#   'produced': '34192592'},
#  87: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '28.1'),
#   'produced': '34192592'},
#  88: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.7', '30.8'),
#   'produced': '34192592'},
#  89: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.2', '27.2'),
#   'produced': '34192592'},
#  90: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '31'),
#   'produced': '34192592'},
#  91: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.3', '32'),
#   'produced': '34192592'},
#  92: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.7', '33.6'),
#   'produced': '34192592'},
#  93: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '30.2'),
#   'produced': '34192592'},
#  94: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.6', '30.9'),
#   'produced': '34192592'},
#  95: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('29', '29.4'),
#   'produced': '34192592'},
#  96: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28', '29.2'),
#   'produced': '34192592'},
#  97: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.1'),
#   'produced': '34192592'},
#  98: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '30.5'),
#   'produced': '34192592'},
#  99: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.9', '29'),
#   'produced': '34192592'},
#  100: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '28.8'),
#   'produced': '34192592'},
#  101: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.2', '32.2'),
#   'produced': '34192592'},
#  102: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.5', '27.3'),
#   'produced': '34192592'},
#  103: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '27.6'),
#   'produced': '34192592'},
#  104: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '26.8'),
#   'produced': '34192592'},
#  105: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28', '30.8'),
#   'produced': '34192592'},
#  106: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '29.8'),
#   'produced': '34192592'},
#  107: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.8'),
#   'produced': '34192592'},
#  108: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '23.8'),
#   'produced': '34192592'},
#  109: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.5', '27'),
#   'produced': '34192592'},
#  110: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.7', '30.8'),
#   'produced': '34192592'},
#  111: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.6', '28.9'),
#   'produced': '34192592'},
#  112: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('26.7', '32.4'),
#   'produced': '34192592'},
#  113: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.8', '28.6'),
#   'produced': '34192592'},
#  114: {'month': '3',
#   'location': 'Cshire',
#   'price/cost': ('29', '31.6'),
#   'produced': '34192592'},
#  115: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.5', '30.5'),
#   'produced': '34192592'},
#  116: {'month': '3',
#   'location': 'Bshire',
#   'price/cost': ('28.1', '30.1'),
#   'produced': '34192592'},
#  117: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.7', '28.7'),
#   'produced': '34192592'},
#  118: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('27.3', '28.3'),
#   'produced': '34192592'},
#  119: {'month': '3',
#   'location': 'Ashire',
#   'price/cost': ('28.4', '30.3'),
#   'produced': '34192592'},
#  120: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.4', '20.9'),
#   'produced': '31210725'},
#  121: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('25.9', '23.1'),
#   'produced': '31210725'},
#  122: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.4', '14.5'),
#   'produced': '31210725'},
#  123: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '21'),
#   'produced': '31210725'},
#  124: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.1', '21.7'),
#   'produced': '31210725'},
#  125: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '24.4'),
#   'produced': '31210725'},
#  126: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.1', '23.8'),
#   'produced': '31210725'},
#  127: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '22.2'),
#   'produced': '31210725'},
#  128: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '25.4'),
#   'produced': '31210725'},
#  129: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.9', '18.3'),
#   'produced': '31210725'},
#  130: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.1', '22.1'),
#   'produced': '31210725'},
#  131: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '23'),
#   'produced': '31210725'},
#  132: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '25.3'),
#   'produced': '31210725'},
#  133: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.2', '23.6'),
#   'produced': '31210725'},
#  134: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.8', '23.4'),
#   'produced': '31210725'},
#  135: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '21.4'),
#   'produced': '31210725'},
#  136: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.4', '25.1'),
#   'produced': '31210725'},
#  137: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '19.6'),
#   'produced': '31210725'},
#  138: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '21.7'),
#   'produced': '31210725'},
#  139: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('27.6', '19.5'),
#   'produced': '31210725'},
#  140: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.7', '25.5'),
#   'produced': '31210725'},
#  141: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '20.2'),
#   'produced': '31210725'},
#  142: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.6', '20.3'),
#   'produced': '31210725'},
#  143: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.5', '21.2'),
#   'produced': '31210725'},
#  144: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.4', '18.2'),
#   'produced': '31210725'},
#  145: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('25.8', '22.8'),
#   'produced': '31210725'},
#  146: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27', '25.4'),
#   'produced': '31210725'},
#  147: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.8', '21.4'),
#   'produced': '31210725'},
#  148: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.6', '22.8'),
#   'produced': '31210725'},
#  149: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27.4', '20.4'),
#   'produced': '31210725'},
#  150: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('26.9', '19.7'),
#   'produced': '31210725'},
#  151: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.2', '22.7'),
#   'produced': '31210725'},
#  152: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '25.4'),
#   'produced': '31210725'},
#  153: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '21.1'),
#   'produced': '31210725'},
#  154: {'month': '8',
#   'location': 'Ashire',
#   'price/cost': ('27', '21.5'),
#   'produced': '31210725'},
#  155: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26.7', '23.2'),
#   'produced': '31210725'},
#  156: {'month': '8',
#   'location': 'Bshire',
#   'price/cost': ('26', '20.5'),
#   'produced': '31210725'},
#  157: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26.3', '24.9'),
#   'produced': '31210725'},
#  158: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('26', '21'),
#   'produced': '31210725'},
#  159: {'month': '8',
#   'location': 'Cshire',
#   'price/cost': ('27.5', '27.7'),
#   'produced': '31210725'},
#  160: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '17.4'),
#   'produced': '30543330'},
#  161: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '20.6'),
#   'produced': '30543330'},
#  162: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '21.2'),
#   'produced': '30543330'},
#  163: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.5', '21.2'),
#   'produced': '30543330'},
#  164: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '24.5'),
#   'produced': '30543330'},
#  165: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.4'),
#   'produced': '30543330'},
#  166: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.1'),
#   'produced': '30543330'},
#  167: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '16.3'),
#   'produced': '30543330'},
#  168: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '22.5'),
#   'produced': '30543330'},
#  169: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '21.7'),
#   'produced': '30543330'},
#  170: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.4', '23.2'),
#   'produced': '30543330'},
#  171: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '24.6'),
#   'produced': '30543330'},
#  172: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.7', '26.2'),
#   'produced': '30543330'},
#  173: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '22.7'),
#   'produced': '30543330'},
#  174: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.5', '24.1'),
#   'produced': '30543330'},
#  175: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '22.6'),
#   'produced': '30543330'},
#  176: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('26.1', '20.9'),
#   'produced': '30543330'},
#  177: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '21.3'),
#   'produced': '30543330'},
#  178: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '19.7'),
#   'produced': '30543330'},
#  179: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '19.4'),
#   'produced': '30543330'},
#  180: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.6', '21.3'),
#   'produced': '30543330'},
#  181: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.1', '23'),
#   'produced': '30543330'},
#  182: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '22.5'),
#   'produced': '30543330'},
#  183: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('24.7', '22.3'),
#   'produced': '30543330'},
#  184: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.4', '26.6'),
#   'produced': '30543330'},
#  185: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25', '19'),
#   'produced': '30543330'},
#  186: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25', '21.1'),
#   'produced': '30543330'},
#  187: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.4', '20.8'),
#   'produced': '30543330'},
#  188: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '21.2'),
#   'produced': '30543330'},
#  189: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.7', '22'),
#   'produced': '30543330'},
#  190: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.6', '20.2'),
#   'produced': '30543330'},
#  191: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.4', '18.6'),
#   'produced': '30543330'},
#  192: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '23.3'),
#   'produced': '30543330'},
#  193: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '20'),
#   'produced': '30543330'},
#  194: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '24.9'),
#   'produced': '30543330'},
#  195: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('25.8', '19.6'),
#   'produced': '30543330'},
#  196: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.2', '24.6'),
#   'produced': '30543330'},
#  197: {'month': '5',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '20.2'),
#   'produced': '30543330'},
#  198: {'month': '5',
#   'location': 'Bshire',
#   'price/cost': ('24.2', '21.2'),
#   'produced': '30543330'},
#  199: {'month': '5',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '19.5'),
#   'produced': '30543330'},
#  200: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.9', '30'),
#   'produced': '33581803'},
#  201: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.3', '29.8'),
#   'produced': '33581803'},
#  202: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.3', '31.2'),
#   'produced': '33581803'},
#  203: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '27.5'),
#   'produced': '33581803'},
#  204: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.5', '27'),
#   'produced': '33581803'},
#  205: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '31'),
#   'produced': '33581803'},
#  206: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.5', '26.5'),
#   'produced': '33581803'},
#  207: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '32.3'),
#   'produced': '33581803'},
#  208: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '28.1'),
#   'produced': '33581803'},
#  209: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.6', '28.7'),
#   'produced': '33581803'},
#  210: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.4', '30.1'),
#   'produced': '33581803'},
#  211: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40', '26.4'),
#   'produced': '33581803'},
#  212: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '26.3'),
#   'produced': '33581803'},
#  213: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '36.9'),
#   'produced': '33581803'},
#  214: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.8', '29.9'),
#   'produced': '33581803'},
#  215: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '32.4'),
#   'produced': '33581803'},
#  216: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.4', '30.2'),
#   'produced': '33581803'},
#  217: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.8', '29.3'),
#   'produced': '33581803'},
#  218: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.3', '30'),
#   'produced': '33581803'},
#  219: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.1', '27'),
#   'produced': '33581803'},
#  220: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34', '26.7'),
#   'produced': '33581803'},
#  221: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.6', '26.9'),
#   'produced': '33581803'},
#  222: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('38.8', '31.2'),
#   'produced': '33581803'},
#  223: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.3', '24.6'),
#   'produced': '33581803'},
#  224: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.9', '31.4'),
#   'produced': '33581803'},
#  225: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '32.8'),
#   'produced': '33581803'},
#  226: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.5', '30.9'),
#   'produced': '33581803'},
#  227: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '30.6'),
#   'produced': '33581803'},
#  228: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.8', '30.5'),
#   'produced': '33581803'},
#  229: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('33.2', '25.7'),
#   'produced': '33581803'},
#  230: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('33.7', '29.8'),
#   'produced': '33581803'},
#  231: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('39.6', '31.9'),
#   'produced': '33581803'},
#  232: {'month': '1',
#   'location': 'Ashire',
#   'price/cost': ('34.2', '31.8'),
#   'produced': '33581803'},
#  233: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.4', '24.4'),
#   'produced': '33581803'},
#  234: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('38.8', '28'),
#   'produced': '33581803'},
#  235: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.3', '27.9'),
#   'produced': '33581803'},
#  236: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.1', '31.7'),
#   'produced': '33581803'},
#  237: {'month': '1',
#   'location': 'Bshire',
#   'price/cost': ('34.5', '32'),
#   'produced': '33581803'},
#  238: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40', '29.9'),
#   'produced': '33581803'},
#  239: {'month': '1',
#   'location': 'Cshire',
#   'price/cost': ('40.2', '27.7'),
#   'produced': '33581803'},
#  240: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '23.2'),
#   'produced': '35301548'},
#  241: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '23.7'),
#   'produced': '35301548'},
#  242: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '21.3'),
#   'produced': '35301548'},
#  243: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.8', '21.7'),
#   'produced': '35301548'},
#  244: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '24'),
#   'produced': '35301548'},
#  245: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.3', '24.6'),
#   'produced': '35301548'},
#  246: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '22.6'),
#   'produced': '35301548'},
#  247: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '21.7'),
#   'produced': '35301548'},
#  248: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.6', '24.1'),
#   'produced': '35301548'},
#  249: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.7', '23'),
#   'produced': '35301548'},
#  250: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.4', '21.4'),
#   'produced': '35301548'},
#  251: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.1', '18.9'),
#   'produced': '35301548'},
#  252: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('26.2', '21.1'),
#   'produced': '35301548'},
#  253: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '25.6'),
#   'produced': '35301548'},
#  254: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('23.9', '22.2'),
#   'produced': '35301548'},
#  255: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25', '23.6'),
#   'produced': '35301548'},
#  256: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '24.1'),
#   'produced': '35301548'},
#  257: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '19.7'),
#   'produced': '35301548'},
#  258: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.5'),
#   'produced': '35301548'},
#  259: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '23'),
#   'produced': '35301548'},
#  260: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '18.7'),
#   'produced': '35301548'},
#  261: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '25.4'),
#   'produced': '35301548'},
#  262: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '21.5'),
#   'produced': '35301548'},
#  263: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('25.5', '22.6'),
#   'produced': '35301548'},
#  264: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '26.8'),
#   'produced': '35301548'},
#  265: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '21.9'),
#   'produced': '35301548'},
#  266: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.8'),
#   'produced': '35301548'},
#  267: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '22.2'),
#   'produced': '35301548'},
#  268: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '21'),
#   'produced': '35301548'},
#  269: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '19.5'),
#   'produced': '35301548'},
#  270: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '21.1'),
#   'produced': '35301548'},
#  271: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.2', '21.1'),
#   'produced': '35301548'},
#  272: {'month': '6',
#   'location': 'Ashire',
#   'price/cost': ('24.8', '20.3'),
#   'produced': '35301548'},
#  273: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25', '22.3'),
#   'produced': '35301548'},
#  274: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('23.9', '24.3'),
#   'produced': '35301548'},
#  275: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('25.7', '18.3'),
#   'produced': '35301548'},
#  276: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.1', '25.3'),
#   'produced': '35301548'},
#  277: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('24.8', '23.3'),
#   'produced': '35301548'},
#  278: {'month': '6',
#   'location': 'Bshire',
#   'price/cost': ('26.2', '18.5'),
#   'produced': '35301548'},
#  279: {'month': '6',
#   'location': 'Cshire',
#   'price/cost': ('25.6', '21.9'),
#   'produced': '35301548'},
#  280: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '28.1'),
#   'produced': '31673550'},
#  281: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28', '25.9'),
#   'produced': '31673550'},
#  282: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.1', '25.7'),
#   'produced': '31673550'},
#  283: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '23.4'),
#   'produced': '31673550'},
#  284: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('29', '22.1'),
#   'produced': '31673550'},
#  285: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '27.1'),
#   'produced': '31673550'},
#  286: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '24.1'),
#   'produced': '31673550'},
#  287: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.1', '27.2'),
#   'produced': '31673550'},
#  288: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '25.7'),
#   'produced': '31673550'},
#  289: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28', '27.7'),
#   'produced': '31673550'},
#  290: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.9', '18.8'),
#   'produced': '31673550'},
#  291: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.9', '27.9'),
#   'produced': '31673550'},
#  292: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28', '25.6'),
#   'produced': '31673550'},
#  293: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.4', '28'),
#   'produced': '31673550'},
#  294: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.7', '25.9'),
#   'produced': '31673550'},
#  295: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.5', '19.7'),
#   'produced': '31673550'},
#  296: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.6', '26.4'),
#   'produced': '31673550'},
#  297: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.1', '25.9'),
#   'produced': '31673550'},
#  298: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.6', '25.1'),
#   'produced': '31673550'},
#  299: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '22.7'),
#   'produced': '31673550'},
#  300: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.4', '29.2'),
#   'produced': '31673550'},
#  301: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '22.8'),
#   'produced': '31673550'},
#  302: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.4', '26.8'),
#   'produced': '31673550'},
#  303: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '20'),
#   'produced': '31673550'},
#  304: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.1', '22.7'),
#   'produced': '31673550'},
#  305: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.7', '22.6'),
#   'produced': '31673550'},
#  306: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.5', '28'),
#   'produced': '31673550'},
#  307: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.1', '25'),
#   'produced': '31673550'},
#  308: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '21.7'),
#   'produced': '31673550'},
#  309: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('28.2', '29.8'),
#   'produced': '31673550'},
#  310: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('29.1', '24.9'),
#   'produced': '31673550'},
#  311: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('28.3', '24.3'),
#   'produced': '31673550'},
#  312: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('27.8', '26.3'),
#   'produced': '31673550'},
#  313: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.5', '23.4'),
#   'produced': '31673550'},
#  314: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.8', '22.6'),
#   'produced': '31673550'},
#  315: {'month': '9',
#   'location': 'Bshire',
#   'price/cost': ('27.3', '27.1'),
#   'produced': '31673550'},
#  316: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('27.5', '26.9'),
#   'produced': '31673550'},
#  317: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.1', '25.5'),
#   'produced': '31673550'},
#  318: {'month': '9',
#   'location': 'Ashire',
#   'price/cost': ('26.5', '28.4'),
#   'produced': '31673550'},
#  319: {'month': '9',
#   'location': 'Cshire',
#   'price/cost': ('28.3', '28.3'),
#   'produced': '31673550'},
#  320: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.8', '24.5'),
#   'produced': '40571096'},
#  321: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.2', '26'),
#   'produced': '40571096'},
#  322: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.2', '24'),
#   'produced': '40571096'},
#  323: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23', '21.7'),
#   'produced': '40571096'},
#  324: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.3', '26.2'),
#   'produced': '40571096'},
#  325: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.6', '24.8'),
#   'produced': '40571096'},
#  326: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.8', '28.4'),
#   'produced': '40571096'},
#  327: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '25.8'),
#   'produced': '40571096'},
#  328: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '25.1'),
#   'produced': '40571096'},
#  329: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.2', '23.7'),
#   'produced': '40571096'},
#  330: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.3', '24.5'),
#   'produced': '40571096'},
#  331: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.1', '19.6'),
#   'produced': '40571096'},
#  332: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.8', '22.6'),
#   'produced': '40571096'},
#  333: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23', '23'),
#   'produced': '40571096'},
#  334: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.7', '27.5'),
#   'produced': '40571096'},
#  335: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.1', '24.7'),
#   'produced': '40571096'},
#  336: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.6', '25.1'),
#   'produced': '40571096'},
#  337: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.6', '27.2'),
#   'produced': '40571096'},
#  338: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '23.6'),
#   'produced': '40571096'},
#  339: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.1', '24.2'),
#   'produced': '40571096'},
#  340: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.4', '17.6'),
#   'produced': '40571096'},
#  341: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.5', '24.1'),
#   'produced': '40571096'},
#  342: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('23.3', '29.9'),
#   'produced': '40571096'},
#  343: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.3', '28'),
#   'produced': '40571096'},
#  344: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.9', '24.8'),
#   'produced': '40571096'},
#  345: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.2', '25.6'),
#   'produced': '40571096'},
#  346: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '24'),
#   'produced': '40571096'},
#  347: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('21.5', '26'),
#   'produced': '40571096'},
#  348: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.5', '22.8'),
#   'produced': '40571096'},
#  349: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('24.1', '30.6'),
#   'produced': '40571096'},
#  350: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('23.7', '25.7'),
#   'produced': '40571096'},
#  351: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.9', '25.5'),
#   'produced': '40571096'},
#  352: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('23.1', '22.3'),
#   'produced': '40571096'},
#  353: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.1', '26'),
#   'produced': '40571096'},
#  354: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.4', '21.4'),
#   'produced': '40571096'},
#  355: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.5', '28.2'),
#   'produced': '40571096'},
#  356: {'month': '4',
#   'location': 'Bshire',
#   'price/cost': ('22.3', '19.6'),
#   'produced': '40571096'},
#  357: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.4', '26.4'),
#   'produced': '40571096'},
#  358: {'month': '4',
#   'location': 'Cshire',
#   'price/cost': ('22.6', '24.5'),
#   'produced': '40571096'},
#  359: {'month': '4',
#   'location': 'Ashire',
#   'price/cost': ('22.6', '29.7'),
#   'produced': '40571096'},
#  360: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.1', '29.8'),
#   'produced': '27967161'},
#  361: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.1', '31'),
#   'produced': '27967161'},
#  362: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.9', '25.7'),
#   'produced': '27967161'},
#  363: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.7', '25.7'),
#   'produced': '27967161'},
#  364: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.6', '23.1'),
#   'produced': '27967161'},
#  365: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '27.2'),
#   'produced': '27967161'},
#  366: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '30.9'),
#   'produced': '27967161'},
#  367: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.5', '29.1'),
#   'produced': '27967161'},
#  368: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.9', '33.3'),
#   'produced': '27967161'},
#  369: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.2', '27.8'),
#   'produced': '27967161'},
#  370: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.4', '26.5'),
#   'produced': '27967161'},
#  371: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('33.9', '28.2'),
#   'produced': '27967161'},
#  372: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('36', '29'),
#   'produced': '27967161'},
#  373: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.1', '32.5'),
#   'produced': '27967161'},
#  374: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.5', '28.5'),
#   'produced': '27967161'},
#  375: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.9', '31'),
#   'produced': '27967161'},
#  376: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41', '28'),
#   'produced': '27967161'},
#  377: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '31.6'),
#   'produced': '27967161'},
#  378: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.8', '31.6'),
#   'produced': '27967161'},
#  379: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.7', '30.5'),
#   'produced': '27967161'},
#  380: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.9', '31.9'),
#   'produced': '27967161'},
#  381: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.8', '27.2'),
#   'produced': '27967161'},
#  382: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.1', '29.4'),
#   'produced': '27967161'},
#  383: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.8', '29.9'),
#   'produced': '27967161'},
#  384: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.3', '29.5'),
#   'produced': '27967161'},
#  385: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.6', '27.1'),
#   'produced': '27967161'},
#  386: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '27.8'),
#   'produced': '27967161'},
#  387: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.9', '29.4'),
#   'produced': '27967161'},
#  388: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.5', '29.5'),
#   'produced': '27967161'},
#  389: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35.2', '25.5'),
#   'produced': '27967161'},
#  390: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.4', '28.7'),
#   'produced': '27967161'},
#  391: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('42.2', '28.6'),
#   'produced': '27967161'},
#  392: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('42', '28.2'),
#   'produced': '27967161'},
#  393: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('35', '28.2'),
#   'produced': '27967161'},
#  394: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('34.8', '24.9'),
#   'produced': '27967161'},
#  395: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('40.4', '29.7'),
#   'produced': '27967161'},
#  396: {'month': '12',
#   'location': 'Cshire',
#   'price/cost': ('41.4', '28.1'),
#   'produced': '27967161'},
#  397: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '31.4'),
#   'produced': '27967161'},
#  398: {'month': '12',
#   'location': 'Ashire',
#   'price/cost': ('34.8', '29.8'),
#   'produced': '27967161'},
#  399: {'month': '12',
#   'location': 'Bshire',
#   'price/cost': ('35.3', '31.7'),
#   'produced': '27967161'},
#  400: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.1', '18.7'),
#   'produced': '36604264'},
#  401: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '22.3'),
#   'produced': '36604264'},
#  402: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.4', '20.8'),
#   'produced': '36604264'},
#  403: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.1', '25.5'),
#   'produced': '36604264'},
#  404: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.8', '23'),
#   'produced': '36604264'},
#  405: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '23.7'),
#   'produced': '36604264'},
#  406: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '22'),
#   'produced': '36604264'},
#  407: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.7', '22.9'),
#   'produced': '36604264'},
#  408: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.7', '22.5'),
#   'produced': '36604264'},
#  409: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.5', '23.9'),
#   'produced': '36604264'},
#  410: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25', '18.7'),
#   'produced': '36604264'},
#  411: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.2', '26.6'),
#   'produced': '36604264'},
#  412: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.8', '17.7'),
#   'produced': '36604264'},
#  413: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('23.9', '19.7'),
#   'produced': '36604264'},
#  414: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '22.4'),
#   'produced': '36604264'},
#  415: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.5', '19.7'),
#   'produced': '36604264'},
#  416: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.6', '25.7'),
#   'produced': '36604264'},
#  417: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.9', '24.7'),
#   'produced': '36604264'},
#  418: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.9', '22.7'),
#   'produced': '36604264'},
#  419: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.2', '21.8'),
#   'produced': '36604264'},
#  420: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.2', '25.9'),
#   'produced': '36604264'},
#  421: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.8', '23.2'),
#   'produced': '36604264'},
#  422: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.7', '19.2'),
#   'produced': '36604264'},
#  423: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.4', '19.8'),
#   'produced': '36604264'},
#  424: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24', '21.8'),
#   'produced': '36604264'},
#  425: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.5', '21.2'),
#   'produced': '36604264'},
#  426: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.3', '27'),
#   'produced': '36604264'},
#  427: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.8', '23.2'),
#   'produced': '36604264'},
#  428: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.1', '25.2'),
#   'produced': '36604264'},
#  429: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.3', '20.9'),
#   'produced': '36604264'},
#  430: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.7', '22'),
#   'produced': '36604264'},
#  431: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('24.6', '24.3'),
#   'produced': '36604264'},
#  432: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('24.9', '23.9'),
#   'produced': '36604264'},
#  433: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('25.3', '21.3'),
#   'produced': '36604264'},
#  434: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.2', '21'),
#   'produced': '36604264'},
#  435: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '24'),
#   'produced': '36604264'},
#  436: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.3', '19.4'),
#   'produced': '36604264'},
#  437: {'month': '7',
#   'location': 'Cshire',
#   'price/cost': ('24.3', '25.7'),
#   'produced': '36604264'},
#  438: {'month': '7',
#   'location': 'Ashire',
#   'price/cost': ('25.6', '22.7'),
#   'produced': '36604264'},
#  439: {'month': '7',
#   'location': 'Bshire',
#   'price/cost': ('25.4', '24.9'),
#   'produced': '36604264'},
#  440: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '25.4'),
#   'produced': '33479143'},
#  441: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.8', '25.7'),
#   'produced': '33479143'},
#  442: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '30.8'),
#   'produced': '33479143'},
#  443: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '30.2'),
#   'produced': '33479143'},
#  444: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.8', '36'),
#   'produced': '33479143'},
#  445: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '27'),
#   'produced': '33479143'},
#  446: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '26.8'),
#   'produced': '33479143'},
#  447: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '31.8'),
#   'produced': '33479143'},
#  448: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('31.9', '30.5'),
#   'produced': '33479143'},
#  449: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.3', '27.3'),
#   'produced': '33479143'},
#  450: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32', '30.9'),
#   'produced': '33479143'},
#  451: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.5', '29.1'),
#   'produced': '33479143'},
#  452: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.9', '26.6'),
#   'produced': '33479143'},
#  453: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('30.8', '28.6'),
#   'produced': '33479143'},
#  454: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '29.3'),
#   'produced': '33479143'},
#  455: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('33.4', '27.9'),
#   'produced': '33479143'},
#  456: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.8', '31.3'),
#   'produced': '33479143'},
#  457: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.5', '27.4'),
#   'produced': '33479143'},
#  458: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('33', '31.6'),
#   'produced': '33479143'},
#  459: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32', '28.4'),
#   'produced': '33479143'},
#  460: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '25.9'),
#   'produced': '33479143'},
#  461: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32', '32.1'),
#   'produced': '33479143'},
#  462: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('31.6', '34.6'),
#   'produced': '33479143'},
#  463: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.2', '30.7'),
#   'produced': '33479143'},
#  464: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '32.9'),
#   'produced': '33479143'},
#  465: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.2', '27.9'),
#   'produced': '33479143'},
#  466: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.7', '32.5'),
#   'produced': '33479143'},
#  467: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.6', '28.1'),
#   'produced': '33479143'},
#  468: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.4', '30.9'),
#   'produced': '33479143'},
#  469: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.8', '32.3'),
#   'produced': '33479143'},
#  470: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.2', '28.4'),
#   'produced': '33479143'},
#  471: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.1', '25.3'),
#   'produced': '33479143'},
#  472: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.5', '25.1'),
#   'produced': '33479143'},
#  473: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('32.8', '25.7'),
#   'produced': '33479143'},
#  474: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.5', '25.6'),
#   'produced': '33479143'},
#  475: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('33.2', '30'),
#   'produced': '33479143'},
#  476: {'month': '11',
#   'location': 'Cshire',
#   'price/cost': ('31.7', '28.1'),
#   'produced': '33479143'},
#  477: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.1', '33.2'),
#   'produced': '33479143'},
#  478: {'month': '11',
#   'location': 'Bshire',
#   'price/cost': ('32.4', '25.9'),
#   'produced': '33479143'},
#  479: {'month': '11',
#   'location': 'Ashire',
#   'price/cost': ('32.5', '28.5'),
#   'produced': '33479143'}}

# %% [markdown]
# ### Task 2 - Writing functions to manipulate your data structure
#
# Write several functions to deal with information stored in your data structure:
#
#
#
# 1. Write a function `filterByRegion(dataStruct, regionString)` that takes your data structure and a string specifying a region as parameters, and returns a new data structure containing only the information for sales from the region specified by `regionString`.
# 2. Write a function `filterByMonth(dataStruct, month)` that takes your data structure and an argument specifying the month as parameters, and returns a new data structure containing only the information for sales from the month specified.
# 3. Write a function` getPricesPerUnit(dataStruct)` that takes your data structure, and returns a list of the prices/unit stored in that data structure (the first column in the file).
# 4. Write a function` getCostsPerUnit(dataStruct)` that takes your data structure, and returns a list of the production cost/unit stored in that data structure (the second column in the file).
# 5. Write a function `calculateProfitPerUnit(dataStruct)` that takes your data structure, and returns a list of the profits for the sales (the difference between the price paid and the costs).

# %%
dataStruct = readPoturnips('poturnip.csv')

def filterByRegion(dataStruct, regionString):
    salesByRegion = {}
    saleNo = 0
    for sale in dataStruct:
        if dataStruct[sale]['location'] == regionString:
            salesByRegion[saleNo] = dataStruct[sale]
            saleNo += 1
    return salesByRegion

def filterByMonth(dataStruct, month):
    salesByMonth = {}
    saleNo = 0
    for sale in dataStruct:
        if int(dataStruct[sale]['month']) == month:
            salesByMonth[saleNo] = dataStruct[sale]
            saleNo += 1
    return salesByMonth
    
def getPricesPerUnit(dataStruct):
    pricesPerUnit = []
    for sale in dataStruct:
        pricesPerUnit.append(dataStruct[sale]['price/cost'][0])
    return pricesPerUnit

def getCostsPerUnit(dataStruct):
    costsPerUnit = []
    for sale in dataStruct:
        costsPerUnit.append(dataStruct[sale]['price/cost'][1])
    return costsPerUnit
    
def calculateProfitPerUnit(dataStruct):
    profit = []
    prices = getPricesPerUnit(dataStruct)
    costs = getCostsPerUnit(dataStruct)
    for i in range(len(prices)):
        profit.append(int(float(prices[i]) - float(costs[i])))
    return profit

calculateProfitPerUnit(dataStruct)
# Out:
# [3,
#  6,
#  8,
#  4,
#  0,
#  2,
#  1,
#  6,
#  6,
#  11,
#  11,
#  4,
#  0,
#  5,
#  11,
#  6,
#  3,
#  0,
#  1,
#  8,
#  6,
#  8,
#  13,
#  3,
#  3,
#  7,
#  8,
#  5,
#  0,
#  0,
#  6,
#  -2,
#  5,
#  6,
#  5,
#  5,
#  2,
#  1,
#  11,
#  9,
#  -2,
#  7,
#  5,
#  4,
#  0,
#  6,
#  5,
#  -1,
#  2,
#  5,
#  0,
#  3,
#  2,
#  2,
#  5,
#  8,
#  9,
#  0,
#  3,
#  6,
#  4,
#  5,
#  2,
#  1,
#  5,
#  8,
#  4,
#  2,
#  7,
#  2,
#  4,
#  5,
#  2,
#  9,
#  1,
#  5,
#  5,
#  0,
#  4,
#  5,
#  1,
#  -2,
#  5,
#  -1,
#  1,
#  -1,
#  -3,
#  0,
#  -3,
#  1,
#  -3,
#  -3,
#  -4,
#  -2,
#  -2,
#  0,
#  -1,
#  0,
#  -2,
#  -1,
#  -1,
#  -4,
#  0,
#  0,
#  1,
#  -2,
#  -2,
#  0,
#  3,
#  1,
#  -2,
#  0,
#  -5,
#  0,
#  -2,
#  -2,
#  -2,
#  0,
#  -1,
#  -1,
#  5,
#  2,
#  11,
#  6,
#  5,
#  2,
#  3,
#  5,
#  2,
#  8,
#  4,
#  4,
#  1,
#  3,
#  3,
#  5,
#  2,
#  7,
#  5,
#  8,
#  1,
#  6,
#  6,
#  5,
#  9,
#  3,
#  1,
#  5,
#  3,
#  7,
#  7,
#  4,
#  2,
#  5,
#  5,
#  3,
#  5,
#  1,
#  5,
#  0,
#  7,
#  4,
#  3,
#  3,
#  1,
#  5,
#  3,
#  8,
#  2,
#  3,
#  2,
#  0,
#  -1,
#  2,
#  0,
#  2,
#  5,
#  3,
#  5,
#  5,
#  4,
#  1,
#  2,
#  2,
#  -1,
#  6,
#  3,
#  4,
#  3,
#  3,
#  5,
#  5,
#  1,
#  4,
#  0,
#  6,
#  0,
#  4,
#  3,
#  5,
#  3,
#  4,
#  8,
#  6,
#  13,
#  3,
#  7,
#  8,
#  6,
#  4,
#  4,
#  13,
#  7,
#  3,
#  3,
#  1,
#  3,
#  4,
#  4,
#  7,
#  7,
#  7,
#  7,
#  15,
#  8,
#  0,
#  2,
#  3,
#  3,
#  7,
#  3,
#  7,
#  2,
#  10,
#  10,
#  6,
#  2,
#  2,
#  10,
#  12,
#  1,
#  1,
#  4,
#  3,
#  0,
#  0,
#  1,
#  2,
#  0,
#  1,
#  3,
#  5,
#  5,
#  0,
#  1,
#  1,
#  1,
#  5,
#  5,
#  2,
#  6,
#  0,
#  4,
#  2,
#  -1,
#  3,
#  2,
#  2,
#  4,
#  5,
#  4,
#  3,
#  4,
#  2,
#  0,
#  7,
#  0,
#  1,
#  7,
#  3,
#  0,
#  2,
#  1,
#  4,
#  6,
#  1,
#  4,
#  0,
#  2,
#  0,
#  9,
#  0,
#  2,
#  0,
#  2,
#  8,
#  1,
#  1,
#  3,
#  5,
#  0,
#  5,
#  0,
#  8,
#  5,
#  5,
#  0,
#  3,
#  6,
#  -1,
#  4,
#  4,
#  1,
#  4,
#  5,
#  0,
#  0,
#  2,
#  -1,
#  0,
#  -1,
#  -3,
#  0,
#  1,
#  -2,
#  -2,
#  -5,
#  -3,
#  -1,
#  0,
#  -1,
#  3,
#  0,
#  0,
#  -4,
#  -1,
#  -1,
#  -3,
#  0,
#  -1,
#  5,
#  0,
#  -6,
#  -5,
#  -1,
#  -3,
#  -1,
#  -4,
#  0,
#  -6,
#  -2,
#  -2,
#  0,
#  -3,
#  1,
#  -5,
#  2,
#  -4,
#  -1,
#  -7,
#  5,
#  10,
#  9,
#  16,
#  11,
#  13,
#  9,
#  12,
#  7,
#  7,
#  8,
#  5,
#  7,
#  7,
#  7,
#  9,
#  13,
#  9,
#  10,
#  10,
#  3,
#  13,
#  5,
#  4,
#  11,
#  8,
#  6,
#  12,
#  12,
#  9,
#  12,
#  13,
#  13,
#  6,
#  9,
#  10,
#  13,
#  3,
#  4,
#  3,
#  5,
#  3,
#  4,
#  0,
#  2,
#  1,
#  2,
#  1,
#  3,
#  0,
#  6,
#  -2,
#  7,
#  4,
#  3,
#  5,
#  0,
#  0,
#  2,
#  3,
#  0,
#  2,
#  5,
#  4,
#  2,
#  3,
#  -1,
#  2,
#  0,
#  4,
#  2,
#  0,
#  1,
#  4,
#  4,
#  0,
#  5,
#  -1,
#  2,
#  0,
#  6,
#  6,
#  1,
#  2,
#  -4,
#  4,
#  4,
#  0,
#  1,
#  4,
#  1,
#  2,
#  5,
#  2,
#  2,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  0,
#  -3,
#  1,
#  -1,
#  4,
#  0,
#  3,
#  0,
#  0,
#  3,
#  6,
#  7,
#  7,
#  6,
#  3,
#  3,
#  -1,
#  6,
#  4]

# %% [markdown]
# ### Task 3 - Extracting information and plotting
#
# Use the functions you wrote as part of Task 2 and any additional bits of code you need to produce a series of plots of your data using `matplotlib`
#
# 1. Produce a scatterplot of the price paid per unit vs the cost of production per unit overall.
# 2. Produce a scatterplot of the price paid per unit vs the total production in the month of sale
# 3. Produce histograms of the profit/unit for each region.

# %%
import matplotlib.pyplot as plt
xVals = getPricesPerUnit(dataStruct)
yVals = getCostsPerUnit(dataStruct)

plt.scatter(xVals, yVals)
plt.xlabel('price paid per unit')
plt.ylabel('cost of production per unit')
# Out:
# Text(0, 0.5, 'cost of production per unit')

# %%
def getProduction(dataStruct):
    production = []
    for sale in dataStruct:
        production.append(dataStruct[sale]['produced'])
    return production

import matplotlib.pyplot as plt
xVals = getPricesPerUnit(dataStruct)
yVals = getProduction(dataStruct)

plt.scatter(xVals, yVals)
plt.xlabel('price paid per unit')
plt.ylabel('total production in the month of sale')
# Out:
# Text(0, 0.5, 'total production in the month of sale')

# %%
Ashire = filterByRegion(dataStruct, 'Ashire')
Bshire = filterByRegion(dataStruct, 'Bshire')
Cshire = filterByRegion(dataStruct, 'Cshire')

plt.hist(calculateProfitPerUnit(Ashire))
plt.title('Ashire Profits')
plt.xlabel('profit per unit')
plt.ylabel('units sold')
plt.show()
plt.hist(calculateProfitPerUnit(Bshire))
plt.title('Bshire Profits')
plt.xlabel('profit per unit')
plt.ylabel('units sold')
plt.show()
plt.hist(calculateProfitPerUnit(Cshire))
plt.title('Cshire Profits')
plt.xlabel('profit per unit')
plt.ylabel('units sold')
plt.show()
